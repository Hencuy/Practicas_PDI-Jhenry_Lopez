# %% [markdown]
# Solarizacion y Polarizacion

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

def solarizar(imagen,umbral):
    img_solarizada = np.where(imagen<umbral,imagen,255-imagen)
    return img_solarizada

def posterizar(imagen,nivel):
    f_nvl = 255/nivel
    img_poster = np.round(imagen/f_nvl)*f_nvl
    return img_poster.astype(np.uint8)

imagen = cv2.imread('Monin.jpeg')
imagen_original = cv2.cvtColor(imagen,cv2.COLOR_RGB2BGR)
img_gris = cv2.cvtColor(imagen,cv2.COLOR_BGR2GRAY)

umbral = 150
img_sol = solarizar(img_gris,umbral)

nivel = 3
img_post = posterizar(img_gris,nivel)

plt.figure(figsize=(10,5))

#Referencia al array de las imagenes
plt.subplot(1,3,1)
plt.imshow(imagen_original,cmap='gray')
plt.title('Imagen incial')

plt.subplot(1,3,2)
plt.imshow(img_sol,cmap='gray')
plt.title('Solarizada')

plt.subplot(1,3,3)
plt.imshow(img_post,cmap='gray')
plt.title('Posterizada')
# Out:
# Text(0.5, 1.0, 'Posterizada')

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [10,5]
tamanio_img = 100

R = np.ones((tamanio_img,tamanio_img))*255
G = np.ones((tamanio_img,tamanio_img))*100
B = np.ones((tamanio_img,tamanio_img))*2

imagen=np.dstack((R,G,B))
imagen=np.array(imagen,dtype = int)

plt.figure()
plt.imshow(imagen)
plt.title('RGB imagen')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

imagen = cv2.imread('Monin.jpeg',cv2.IMREAD_GRAYSCALE)

img2 = cv2.imread('Monin.jpeg')

img_original = cv2.cvtColor(img2,cv2.COLOR_RGB2BGR)

negativo = 255 - imagen
negativo2 = 255 - img_original

plt.figure(figsize=[10,5])

plt.subplot(2,2,1)
plt.imshow(imagen,cmap='gray')
plt.title('Original Gris')

plt.subplot(2,2,2)
plt.imshow(negativo,cmap='gray')
plt.title('Negativo')

plt.subplot(2,2,3)
plt.imshow(img_original,cmap='gray')
plt.title('Original a Color')

plt.subplot(2,2,4)
plt.imshow(negativo2,cmap='gray')
plt.title('Negativo 2')

plt.tight_layout()
plt.show()
