# %% [markdown]
# Algoritmo de Suma constante para la modificacion del brillo de una imagen

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def suma_constante_brillo(imagen, constante):
    imagen_aumentada = np.clip(imagen.astype(int) + constante, 0, 255).astype(np.uint8)
    return imagen_aumentada


imagen = cv2.imread('Monin.jpeg')

brillo = -100
# Ajustar el brillo usando suma constante
imagen_brillo_suma = suma_constante_brillo(imagen, brillo)


plt.figure(figsize=(15, 5))

plt.subplot(1, 4, 1)
plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))
plt.title('Original')

plt.subplot(1, 4, 2)
plt.imshow(cv2.cvtColor(imagen_brillo_suma, cv2.COLOR_BGR2RGB))
plt.title('Suma constante')
# Out:
# Text(0.5, 1.0, 'Suma constante')
