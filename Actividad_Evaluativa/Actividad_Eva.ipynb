# %% [markdown]
# Actividad Evaluativa
# Ejercicio 1.
# Recorta el punto de interés de la imagen1.jpg tal cual se muestra en la figura, guarda la
# imagen recortada en tu disco local, y muestra la imagen original y la recortada con axis
# (imagen a colores)

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=[10,5]

img_cancerbgr = cv2.imread('imagen1.jpg')
img_cancerrgb = plt.imread('imagen1.jpg')


imagen2 = cv2.cvtColor(img_cancerbgr,cv2.COLOR_RGB2BGR)

imagen_recortada = imagen2[600:800,650:850,:]
cv2.imwrite('recortado.jpg',imagen_recortada)

imagen_guardada = cv2.imread('recortado.jpg')

plt.subplot(121)
plt.title('original')
plt.imshow(imagen2,cmap='gray')

plt.subplot(122)
plt.title('recortado')
plt.imshow(imagen_guardada,cmap='gray')

plt.show()

# %% [markdown]
# Ejercicio 2.
# Genera un degradado lineal a colores.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

width = 300
height = 200


desgradado = Image.new("L", (width, height))


for y in range(height):
    for x in range(width):
    
        gray_value = int(255 * y / height)
        desgradado.putpixel((x, y),gray_value)


convertido = np.array(desgradado)


plt.figure(figsize=(35,30))
plt.subplot(4, 4, 1)
plt.title('Degradado Lineal')
plt.imshow(desgradado)

# %% [markdown]
# Ejercicio 3.
# Genera una imagen semejante a un tablero de ajedrez tomando en cuenta que cada
# casilla debe medir 100x100 px

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

color = [0,0,0]
filas, columnas = 800, 800
simbolo = columnas/8
imagen = np.ones((filas, columnas, 3)) 



def pintar(img,x0,x1,y0,y1,color):
    for x in range(int(x0),int(x1)):
        for y in range(int(y0),int(y1)):
            img[x][y] = np.array(color) 

            

for i in range(8):
    for j in range(8):
        if (i+j)%2==1: 
            pintar(imagen,i*nI,(i+1)*nI,j*simbolo,(j+1)*simbolo,color) 


plt.imshow(imagen)
plt.show()

# %% [markdown]
# Ejercicio 4.
# Tomando en cuenta el ejercicio 2 aplica la ecualización del histograma y muestra el
# mismo viendo las diferencias entre imágenes e histogramas.

# %% [markdown]
# Ejercicio 5.
# Tomando en cuenta la imagen1.jpg aplica un degradado lineal en ella.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

width = 300
height = 200


desgradado = Image.('imagen1.jpg')



for y in range(height):
    for x in range(width):
    
        gray_value = int(255 * y / height)
        desgradado.putpixel((x, y),gray_value)


convertido = np.array(desgradado)


plt.figure(figsize=(35,30))
plt.subplot(4, 4, 1)
plt.title('Degradado Lineal')
plt.imshow(desgradado)
